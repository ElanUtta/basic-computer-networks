# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
G = nx.florentine_families_graph()

# %%
pos = nx.fruchterman_reingold_layout(G) 
#nx.draw_networkx_nodes(G, pos, node_size=25)
#nx.draw_networkx_edges(G, pos, alpha=1, )
#nx.dijkstra_path(G, pos['Medici'])
nx.draw_networkx(G, pos)
print(G)
print(pos)
# Out:
# {'Acciaiuoli': array([0.32601501, 0.5011222 ]), 'Medici': array([0.17897623, 0.17929147]), 'Castellani': array([-0.55340696,  0.27945333]), 'Peruzzi': array([-0.71027161,  0.01211405]), 'Strozzi': array([-0.50466083,  0.04030287]), 'Barbadori': array([-0.1920004 ,  0.38061317]), 'Ridolfi': array([-0.15588206,  0.09337917]), 'Tornabuoni': array([-0.00969523, -0.09242967]), 'Albizzi': array([ 0.22434973, -0.19200806]), 'Salviati': array([0.65061058, 0.19461336]), 'Pazzi': array([1.        , 0.12004452]), 'Bischeri': array([-0.49985523, -0.23413782]), 'Guadagni': array([-0.12256974, -0.39075161]), 'Ginori': array([ 0.51861215, -0.14519917]), 'Lamberteschi': array([-0.15022164, -0.74640783])}

# %%
s = nx.path_graph(5)
nx.dijkstra_path(s, 0, 2)

res = nx.dijkstra_path(G, 'Pazzi','Bischeri')
res # O menor caminho
# Out:
# ['Pazzi', 'Salviati', 'Medici', 'Ridolfi', 'Strozzi', 'Bischeri']
